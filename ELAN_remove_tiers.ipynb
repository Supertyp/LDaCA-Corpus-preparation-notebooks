# %% [markdown]
# ## ELAN remove tiers
#
# remove all tiers from ELAN files which are not wanted
#
# 1. load the files
# 2. identify tiers to remove
# 3. remove the tiers
# 4. save the files

# %%
# find all tiers

import os
import xml.etree.ElementTree as ET


def extract_tier_ids(folder_path):
    tier_ids = set()  # Use a set to avoid duplicate values

    for filename in os.listdir(folder_path):
        if filename.endswith(".eaf"):
            file_path = os.path.join(folder_path, filename)
            #print (file_path)
            try:
                # Parse the XML file
                tree = ET.parse(file_path)
                root = tree.getroot()
                for tier in root.findall(".//TIER"):
                    attributes = tier.attrib
                    tier_ids.add(attributes['TIER_ID'])
                

            except Exception as e:
                print(f"Error processing file {file_path}: {e}")

    return list(tier_ids)

# Example usage
folder_path = './Elan_edited/'
tier_ids_list = extract_tier_ids(folder_path)

# Print the list of unique "TIER_ID" values
print("List of TIER_ID values:")
print(tier_ids_list)
for each in sorted(tier_ids_list):
    print (each)
# Out:
# List of TIER_ID values:
# ['PNT: Dennis', 'PNT: Dorothy', 'PNT: Jeanie', 'Me_possesive', 'Pacific_PNT: Amelia', 'Pacific_PNT: Cameron', 'LaB-CATT_Corrections', 'PNT: Nigel', 'PNT: Jocelyn', 'PNT: Sandra', 'Pacific_PNT: Nadia', 'SP: Male2', 'PNT: Maruccia', 'PNT: Alena', 'INT: Angela', 'Pacific_PNT: Renata', 'LaBB-CAT_PNT: Demitrius', 'PNT: Janice', 'LaBB-CAT_PNT: Jacqueline', 'Pacific_PNT: Nate', 'INT: Lucy', 'PNT: Liliana', 'LaBB-CAT_PNT: Aida', 'Pacific_PNT: Fabio', 'LaBB-CAT_PNT: Fred', 'INT: Beth', 'PNT: Alonso', 'PNT: Kim', 'LaBB-CAT_PNT: Emma', 'Pacific_PNT: Jaden', 'Pacific_PNT: Carlotta', 'PNT: Geoff', 'LaBB-CAT_PNT: Tammy', 'Pacific_PNT: Roseta', 'LaBB-CAT_PNT: Mable', 'LaBB-CAT_PNT: Naomi', 'LaBB-CAT_PNT: Donatella', 'PNT: Brittany', 'SP: Paul', 'Pacific_PNT: Nathaniel', 'PNT: Carmel', 'Pacific_PNT: Emilio', 'Pacific_INT: Brett', 'PNT: Alison', 'PNT: Darlene', 'Pacific_PNT: Bridget', 'LaBB-CAT_PNT: Lily', 'PNT: Danielle', 'LaBB-CAT_PNT: Callum', 'PNT: Pete', 'LaBB-CAT_PNT: Diego', 'PNT: David', 'Australian English', 'LaBB-CAT_PNT: Daria', 'PNT: Deidre', 'PNT: Tony', 'Pacific_PNT: Pablo', 'PNT: Gemma', 'PNT: Merl', 'er', 'SP2: Male', 'SP: female1', 'INT: Jan', 'Pacific_PNT: Jacqueline', 'Pacific_SP: Daria', 'LaBB-CAT_PNT: Leonard', 'LaBB-CAT_PNT: Deborah', 'LaBB-CAT_PNT: Simone', 'PNT: Amar', 'Pacific_INT: Daniel', 'Pacific_PNT: Isaac', 'LaBB-CAT_PNT: Dorothy', 'LaBB:CAT_PNT: Deidre', 'Pacific_PNT: Amar', 'LaBB-CAT_PNT: Alena', 'P
# PNT: Robin
# PNT: Roger
# PNT: Roseta
# PNT: Ruth
# PNT: Ryan
# PNT: Sadie
# PNT: Sally
# PNT: Samantha
# PNT: Samuel
# PNT: Sandra
# PNT: Sara
# PNT: Sarah
# PNT: Shelley
# PNT: Sienna
# PNT: Simon
# PNT: Simone
# PNT: Sophia
# PNT: Stefano
# PNT: Steven
# PNT: Stuart
# PNT: Tammy
# PNT: Tessa
# PNT: Theodore
# PNT: Tim
# PNT: Toby
# PNT: Tom
# PNT: Tony
# PNT: Trevor
# PNT: Violetta
# PNT: Vittorio
# PNT: Warren
# PNT: Whitney
# PNT: Wilma
# PNT: Woodrow
# PNT: Zander
# Pacific_INT: Alice
# Pacific_INT: Ann
# Pacific_INT: Brett
# Pacific_INT: Chloe
# Pacific_INT: Daniel
# Pacific_INT: Ella
# Pacific_INT: Emma
# Pacific_INT: Hannah
# Pacific_INT: Heather
# Pacific_INT: Jill
# Pacific_INT: Simon
# Pacific_INT: Stella
# Pacific_INT: Tania
# Pacific_PNT: Aaron
# Pacific_PNT: Abigail
# Pacific_PNT: Adam
# Pacific_PNT: Aida
# Pacific_PNT: Alberto
# Pacific_PNT: Alec
# Pacific_PNT: Alena
# Pacific_PNT: Alexi
# Pacific_PNT: Alison
# Pacific_PNT: Amanda
# Pacific_PNT: Amar
# Pacific_PNT: Amelia
# Pacific_PNT: Anita
# Pacific_PNT: Anna
# Pacific_PNT: Annie
# Pacific_PNT: Apollo
# Pacific_PNT: Athena
# Pacific_PNT: Bailey
# Pacific_PNT: Bridget
# Pacific_PNT: Callum
# Pacific_PNT: Cameron
# Pacific_PNT: Carlotta
# Pacific_PNT: Carmel
# Pacific_PNT: Cassandra
# Pacific_PNT: Caterina
# Pacific_PNT: Cecilia
# Pacific_PNT: Cora
# Pacific_PNT: Craig
# Pacific_PNT: Damien
# Pacific_PNT: Danielle
# Pacific_PNT: Daria
# Pacific_PNT: Dario
# Pacific_PNT: Darlene
# Pacific_PNT: Deborah
# Pacific_PNT: Demitrius
# Pacific_PNT: Dennis
# Pacific_PNT: Diana
# Pacific_PNT: Diego
# Pacific_PNT: Dina
# Pacific_PNT: Donatella
# Pacific_PNT: Dorothy
# Pacific_PNT: Douglas
# Pacific_PNT: Elaine
# Pacific_PNT: Emilio
# Pacific_PNT: Emma
# Pacific_PNT: Enrico
# Pacific_PNT: Fabio
# Pacific_PNT: Federica
# Pacific_PNT: Flynn
# Pacific_PNT: Gabriella
# Pacific_PNT: Gemma
# Pacific_PNT: Geoff
# Pacific_PNT: Gillian
# Pacific_PNT: Giorgia
# Pacific_PNT: Giovanni
# Pacific_PNT: Glenn
# Pacific_PNT: Gordon
# Pacific_PNT: Hayley
# Pacific_PNT: Isaac
# Pacific_PNT: Jacqueline
# Pacific_PNT: Jaden
# Pacific_PNT: James
# Pacific_PNT: Jasmine
# Pacific_PNT: Jeremy
# Pacific_PNT: Jocelyn
# Pacific_PNT: Julia
# Pacific_PNT: Kaleb
# Pacific_PNT: Katie
# Pacific_PNT: Katrina
# Pacific_PNT: Kenneth
# Pacific_PNT: Kylie
# Pacific_PNT: Larry
# Pacific_PNT: Lathan
# Pacific_PNT: Laura
# Pacific_PNT: Lewis
# Pacific_PNT: Liliana
# Pacific_PNT: Lorenzo
# Pacific_PNT: Lydia
# Pacific_PNT: Manuel
# Pacific_PNT: Marianna
# Pacific_PNT: Mario
# Pacific_PNT: Mark
# Pacific_PNT: Marshall
# Pacific_PNT: Maruccia
# Pacific_PNT: Matthew
# Pacific_PNT: Max
# Pacific_PNT: Melissa
# Pacific_PNT: Meredith
# Pacific_PNT: Monica
# Pacific_PNT: Nadia
# Pacific_PNT: Naomi
# Pacific_PNT: Nate
# Pacific_PNT: Nathaniel
# Pacific_PNT: Nicholas
# Pacific_PNT: Nigel
# Pacific_PNT: Nikola
# Pacific_PNT: Pablo
# Pacific_PNT: Paige
# Pacific_PNT: Paolo
# Pacific_PNT: Parker
# Pacific_PNT: Patrick
# Pacific_PNT: Paul
# Pacific_PNT: Perry
# Pacific_PNT: Phoebe
# Pacific_PNT: Pietro
# Pacific_PNT: Rachel
# Pacific_PNT: Reid
# Pacific_PNT: Renata
# Pacific_PNT: Rhys
# Pacific_PNT: Roseta
# Pacific_PNT: Sadie
# Pacific_PNT: Sally
# Pacific_PNT: Samuel
# Pacific_PNT: Sandra
# Pacific_PNT: Sarah
# Pacific_PNT: Sienna
# Pacific_PNT: Simon
# Pacific_PNT: Simone
# Pacific_PNT: Sophia
# Pacific_PNT: Stefano
# Pacific_PNT: Stuart
# Pacific_PNT: Toby
# Pacific_PNT: Tom
# Pacific_PNT: Tony
# Pacific_PNT: Trevor
# Pacific_PNT: Vittorio
# Pacific_PNT: Zander
# Pacific_SP1: Female
# Pacific_SP1: Kimberley
# Pacific_SP: Apollo
# Pacific_SP: Daria
# Pacific_SP: Female
# Pacific_SP: Female1
# Pacific_SP: Male
# Pacific_SP: Male1
# Paciifc_INT: Jill
# Powerhouse
# Quotatives
# SP1: Boy
# SP1: Carlotta
# SP1: Carmel
# SP1: Child
# SP1: Daughter
# SP1: Father
# SP1: Female
# SP1: Laura
# SP1: Lorenzo
# SP1: Male
# SP1: Others
# SP1: Sofie
# SP1: Victor
# SP1: Wife
# SP1: other
# SP2: Daughter
# SP2: Female
# SP2: Male
# SP2: Mother
# SP3: Female
# SP3: Male
# SP4: Amar
# SP: Apollo
# SP: Arthur
# SP: Danielle
# SP: Daria
# SP: Diego
# SP: Female1
# SP: Giorgia
# SP: Kimberley
# SP: Madison
# SP: Male1
# SP: Male2
# SP: Max
# SP: Paul
# SP: Richard
# SP: Sally
# SP: Sienna
# SP: Simone
# SP: Tony
# SP: female1
# SP: male1
# Sample
# Section to edit
# Sections
# Silence
# Social_Info
# Social_info
# SydSpk App
# SydSpks App
# There's
# Transcription training
# Word_list
# allTextSplit
# all_tiers
# alltextSplit
# er

# %%
import os
import xml.etree.ElementTree as ET

removeList = ["Demographic_info", "Word_list", "Comments", "Section to edit", "Australian_English", "Sections",
             "Comments CT", "Comments KG", "Social_info" ]

startList = ["Pacific"]

def remove_tags_by_attribute(xml_file_path, output_folder, remove_list):
    # Parse the XML file
    tree = ET.parse(xml_file_path)
    root = tree.getroot()

    for each in removeList: 
        # Find and remove specific "TIER" tags based on the "TIER_ID" attribute
        for tier in root.findall(".//TIER[@TIER_ID='" + each + "']"):
            root.remove(tier)
    
    for wordBeginning in startList: 
        # Find and remove specific "TIER" tags based on the "TIER_ID" attribute
        
        for tier in root.findall(".//TIER"):
            attributes = tier.attrib
            if attributes['TIER_ID'].startswith(wordBeginning):
                print(f"Attributes for TIER tag: {attributes}")
                root.remove(tier)
    

    # Save the modified XML to the output folder
    output_file_path = os.path.join(output_folder, os.path.basename(xml_file_path))
    tree.write(output_file_path, encoding="utf-8", xml_declaration=True)

# Example usage
input_folder_path = 'C:\\Users\\barth\\Documents\\LDACA\\AusESL\\edited_elan\\'
output_folder_path = 'C:\\Users\\barth\\Documents\\LDACA\\AusESL\\edited_elan\\'
#attribute_value_to_remove = 'your_target_value'

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# Process each XML file in the input folder
for xml_file_path in os.listdir(input_folder_path):
    if xml_file_path.endswith(".eaf"):
        
        xml_file_path_full = os.path.join(input_folder_path, xml_file_path)
        #print (xml_file_path_full)
        remove_tags_by_attribute(xml_file_path_full, output_folder_path, removeList)
        #print(f"File {xml_file_path_full} processed and saved to {output_folder_path}")

print ("+++ DONE +++")
# Out:
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Stella '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Sylvie'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Sylvie'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Tanya '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Kelsey '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Sylvie'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Sylvie'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Joyce '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Rosa '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Brett'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Brett'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Ruby '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Brett'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Mei '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Liu '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Sylvie'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Sylvie'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Ning '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Brett'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Liling '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Brett'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Mingzhu '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Brett'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Xiulan '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Lanfen '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Sylvie'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Sylvie'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Yanyu '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Brett'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Li '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: William'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Brett'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Jennifer '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Sylvie'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Jia '}
# Attributes for TIER tag: {'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Brett'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Daiyu '}
# Attributes for TIER tag: {'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Xinyue'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Suyin '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Brett'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Yin '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Sylvie'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Carl '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Sylvie'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Bojing '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Sylvie'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Lawrence '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Carrie'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Brett'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Xiaobo '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Shirong '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Sylvie'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Yongrui '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Brett'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Xinyue'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Bolin '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Yunru '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Xinyue'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Anastasia '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Katya'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Katya'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Mila '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_SP1: Nikolai'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Katya'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Melania '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Katya'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Natasha '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Katya'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Alenka '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Katya'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Lidia '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Katya'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Rita '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Yelena'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Victoria '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Yelena'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Elena '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Yelena'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Valerie '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Katya'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Mikhaila '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Katya'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Mischa '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Yelena'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Karina '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Yelena'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Ivana '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Yelena'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Nikola '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Ingrid '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Yelena'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Alina '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Katya'}
# Attributes for TIER tag: {'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Katya'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Yana '}
# Attributes for TIER tag: {'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Katya'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Malvina '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Katya'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Sergey '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Katya'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Stefan '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Yelena'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Anton '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Yelena'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Stas '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Yelena'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Markov '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Katya'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Andrei '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Stepan '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Katya'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Demid '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Yelena'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Yelena'}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Adrik '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'us', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_PNT: Slava '}
# Attributes for TIER tag: {'DEFAULT_LOCALE': 'es', 'LINGUISTIC_TYPE_REF': 'default', 'TIER_ID': 'Pacific_INT: Yelena'}
# +++ DONE +++
